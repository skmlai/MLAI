# %% [markdown]
# # Load the image and find the following properties:
# 1.Size and shape of the image
# 2. The color space model
# 3. Display using cv and matplotlib

# %%
import cv2

# %%
image=cv2.imread('images/lenna1.png')

# %%
height,weidth=image.shape[:2]
print("Weidth:",weidth)
print("Height:",height)
# Out:
# Weidth: 512
# Height: 512

# %% [markdown]
# # Display using cv

# %%
import cv2
path=r"C:\Users\rajesh\images\river.jpg"

image=cv2.imread(path)

cv2.imshow('Image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 2. The color space model

# %%
import matplotlib.pyplot as plt

# %%
path=r"C:\Users\rajesh\images\river.jpg"
image_plt=plt.imread(path)
plt.subplot(1,3,1)
plt.imshow(image_plt,"Greens")
plt.subplot(1,3,2)
plt.imshow(image_plt,"Blues")
plt.subplot(1,3,3)
plt.imshow(image_plt,"Reds")

# %% [markdown]
# # Display using matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
path=r"C:\Users\rajesh\images\river.jpg"

image_plt=plt.imread(path)
plt.imshow(image_plt)

# %% [markdown]
# # Show the image in the matrix 5x5 with following colormaps:
# 1.coolwarm
# 2. rainbow
# 3. tab10
# 4. seismic
# 5. twilight
# 6.turbo
# 7. BuGn

# %% [markdown]
# # Change the pixcels from (100,150) to (200,350) to white color

# %% [markdown]
# # Download the video nature.mp4
# 1. Find height, width, total frames and fps of the video
# 2. Play the video frames
# 3. Save the image at 50th seconds
