# %%
### create the the Data Set

# %%
dataset = [
    ['Apple','Beer','Rice','Chicken'],
    ['Apple','Beer','Rice'],
    ['Apple','Beer'],
    ['Apple','Pear'],
    ['Milk','Beer','Rice','Chicken'],
    ['Milk','Beer','Rice'],
    ['Milk','Beer'],
    ['Milk','Pear']
]

# %%
dataset
# Out:
# [['Apple', 'Beer', 'Rice', 'Chicken'],
#  ['Apple', 'Beer', 'Rice'],
#  ['Apple', 'Beer'],
#  ['Apple', 'Pear'],
#  ['Milk', 'Beer', 'Rice', 'Chicken'],
#  ['Milk', 'Beer', 'Rice'],
#  ['Milk', 'Beer'],
#  ['Milk', 'Pear']]

# %%
# Convert into Structure formate

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
te=TransactionEncoder()
encoded=te.fit_transform(dataset)

# %%
encoded
# Out:
# array([[ True,  True,  True, False, False,  True],
#        [ True,  True, False, False, False,  True],
#        [ True,  True, False, False, False, False],
#        [ True, False, False, False,  True, False],
#        [False,  True,  True,  True, False,  True],
#        [False,  True, False,  True, False,  True],
#        [False,  True, False,  True, False, False],
#        [False, False, False,  True,  True, False]])

# %%
te.columns_
# Out:
# ['Apple', 'Beer', 'Chicken', 'Milk', 'Pear', 'Rice']

# %%
df=pd.DataFrame(encoded, columns=te.columns_)

# %%
df
# Out:
#    Apple   Beer  Chicken   Milk   Pear   Rice
# 0   True   True     True  False  False   True
# 1   True   True    False  False  False   True
# 2   True   True    False  False  False  False
# 3   True  False    False  False   True  False
# 4  False   True     True   True  False   True
# 5  False   True    False   True  False   True
# 6  False   True    False   True  False  False
# 7  False  False    False   True   True  False

# %%
### apply algorithm

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules

# %%
# Find frequent itemset
fre_itemset=fpgrowth(df, min_support=0.25, use_colnames=True)

# %%
fre_itemset
# Out:
#     support               itemsets
# 0     0.750                 (Beer)
# 1     0.500                 (Rice)
# 2     0.500                (Apple)
# 3     0.250              (Chicken)
# 4     0.250                 (Pear)
# 5     0.500                 (Milk)
# 6     0.500           (Rice, Beer)
# 7     0.375          (Apple, Beer)
# 8     0.250          (Rice, Apple)
# 9     0.250    (Rice, Apple, Beer)
# 10    0.250        (Rice, Chicken)
# 11    0.250        (Chicken, Beer)
# 12    0.250  (Chicken, Rice, Beer)
# 13    0.375           (Milk, Beer)
# 14    0.250           (Milk, Rice)
# 15    0.250     (Milk, Rice, Beer)

# %%
# Find frequent itemset
fre_itemset=apriori(df, min_support=0.25, use_colnames=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Find frequent itemset
# ----> 2 fre_itemset=apriori(df, min_support=0.25, use_colnames=True)
#
# NameError: name 'apriori' is not defined

# %%
fre_itemset
# Out:
#     support               itemsets
# 0     0.750                 (Beer)
# 1     0.500                 (Rice)
# 2     0.500                (Apple)
# 3     0.250              (Chicken)
# 4     0.250                 (Pear)
# 5     0.500                 (Milk)
# 6     0.500           (Rice, Beer)
# 7     0.375          (Apple, Beer)
# 8     0.250          (Rice, Apple)
# 9     0.250    (Rice, Apple, Beer)
# 10    0.250        (Rice, Chicken)
# 11    0.250        (Chicken, Beer)
# 12    0.250  (Chicken, Rice, Beer)
# 13    0.375           (Milk, Beer)
# 14    0.250           (Milk, Rice)
# 15    0.250     (Milk, Rice, Beer)

# %%
rules=association_rules(fre_itemset,metric='confidence', min_threshold=0.5)

# %%
rules.shape
# Out:
# (28, 10)

# %%
rules
# Out:
#         antecedents      consequents  antecedent support  ...  leverage  conviction  zhangs_metric
# 0            (Rice)           (Beer)               0.500  ...    0.1250         inf       0.500000
# 1            (Beer)           (Rice)               0.750  ...    0.1250        1.50       1.000000
# 2           (Apple)           (Beer)               0.500  ...    0.0000        1.00       0.000000
# 3            (Beer)          (Apple)               0.750  ...    0.0000        1.00       0.000000
# 4            (Rice)          (Apple)               0.500  ...    0.0000        1.00       0.000000
# 5           (Apple)           (Rice)               0.500  ...    0.0000        1.00       0.000000
# 6     (Rice, Apple)           (Beer)               0.250  ...    0.0625         inf       0.333333
# 7      (Rice, Beer)          (Apple)               0.500  ...    0.0000        1.00       0.000000
# ...

# %%
# antecedents means this
# consequents means that

# %%
rules = rules[['antecedents','consequents','support','confidence']]

# %%
rules
# Out:
#         antecedents      consequents  support  confidence
# 0            (Rice)           (Beer)    0.500    1.000000
# 1            (Beer)           (Rice)    0.500    0.666667
# 2           (Apple)           (Beer)    0.375    0.750000
# 3            (Beer)          (Apple)    0.375    0.500000
# 4            (Rice)          (Apple)    0.250    0.500000
# 5           (Apple)           (Rice)    0.250    0.500000
# 6     (Rice, Apple)           (Beer)    0.250    1.000000
# 7      (Rice, Beer)          (Apple)    0.250    0.500000
# 8     (Apple, Beer)           (Rice)    0.250    0.666667
# 9            (Rice)    (Apple, Beer)    0.250    0.500000
# 10          (Apple)     (Rice, Beer)    0.250    0.500000
# 11           (Rice)        (Chicken)    0.250    0.500000
# 12        (Chicken)           (Rice)    0.250    1.000000
# 13        (Chicken)           (Beer)    0.250    1.000000
# 14  (Rice, Chicken)           (Beer)    0.250    1.000000
# ...

# %%
rules.sort_values(by=['confidence','support'], ascending=False)
# Out:
#         antecedents      consequents  support  confidence
# 0            (Rice)           (Beer)    0.500    1.000000
# 6     (Rice, Apple)           (Beer)    0.250    1.000000
# 12        (Chicken)           (Rice)    0.250    1.000000
# 13        (Chicken)           (Beer)    0.250    1.000000
# 14  (Rice, Chicken)           (Beer)    0.250    1.000000
# 15  (Chicken, Beer)           (Rice)    0.250    1.000000
# 17        (Chicken)     (Rice, Beer)    0.250    1.000000
# 23     (Milk, Rice)           (Beer)    0.250    1.000000
# 2           (Apple)           (Beer)    0.375    0.750000
# 19           (Milk)           (Beer)    0.375    0.750000
# 1            (Beer)           (Rice)    0.500    0.666667
# 8     (Apple, Beer)           (Rice)    0.250    0.666667
# 24     (Milk, Beer)           (Rice)    0.250    0.666667
# 3            (Beer)          (Apple)    0.375    0.500000
# 20           (Beer)           (Milk)    0.375    0.500000
# ...

# %%
# above 50% selection  # Filter the rules

# %%
nrules = rules[rules['confidence']>0.5]

# %%
nrules
# Out:
#         antecedents   consequents  support  confidence
# 0            (Rice)        (Beer)    0.500    1.000000
# 1            (Beer)        (Rice)    0.500    0.666667
# 2           (Apple)        (Beer)    0.375    0.750000
# 6     (Rice, Apple)        (Beer)    0.250    1.000000
# 8     (Apple, Beer)        (Rice)    0.250    0.666667
# 12        (Chicken)        (Rice)    0.250    1.000000
# 13        (Chicken)        (Beer)    0.250    1.000000
# 14  (Rice, Chicken)        (Beer)    0.250    1.000000
# 15  (Chicken, Beer)        (Rice)    0.250    1.000000
# 17        (Chicken)  (Rice, Beer)    0.250    1.000000
# 19           (Milk)        (Beer)    0.375    0.750000
# 23     (Milk, Rice)        (Beer)    0.250    1.000000
# 24     (Milk, Beer)        (Rice)    0.250    0.666667

# %%
nrules.shape
# Out:
# (13, 4)

# %%
nrules75 = rules[rules['confidence']>0.85]

# %%
nrules75
# Out:
#         antecedents   consequents  support  confidence
# 0            (Rice)        (Beer)     0.50         1.0
# 6     (Rice, Apple)        (Beer)     0.25         1.0
# 12        (Chicken)        (Rice)     0.25         1.0
# 13        (Chicken)        (Beer)     0.25         1.0
# 14  (Rice, Chicken)        (Beer)     0.25         1.0
# 15  (Chicken, Beer)        (Rice)     0.25         1.0
# 17        (Chicken)  (Rice, Beer)     0.25         1.0
# 23     (Milk, Rice)        (Beer)     0.25         1.0

# %%
nrules[nrules['antecedents']=={'Rice'}]
# Out:
#   antecedents consequents  support  confidence
# 0      (Rice)      (Beer)      0.5         1.0

# %%
nrules[nrules['antecedents']=={'Rice'}]['consequents']
# Out:
# 0    (Beer)
# Name: consequents, dtype: object

# %%
nrules[nrules['antecedents']=={'Apple','Beer'}]['consequents']
# Out:
# 8    (Rice)
# Name: consequents, dtype: object

# %%
nrules.to_csv('rules.csv',index=False)
