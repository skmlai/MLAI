# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([500,800,300,600,900,700,400])

# %%
# define a function wich will return the scalled value
def scaler(x):
    x_new = ((x-x.min()) / (x.max() - x.min()))
    return x_new

# %%
scaler(x)
# Out:
# array([0.33333333, 0.83333333, 0.        , 0.5       , 1.        ,
#        0.66666667, 0.16666667])

# %%
x= np.array([67,34,58,72,15,89,54,22])

# %%
scaler(x)
# Out:
# array([0.7027027 , 0.25675676, 0.58108108, 0.77027027, 0.        ,
#        1.        , 0.52702703, 0.09459459])

# %%
# Dataset: Social_Network_Ads.csv
# Location https://mitu.co.in/dataset

# %%
df=pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
x=df[['Age','EstimatedSalary']]

# %%
plt.scatter(x['Age'],x['EstimatedSalary'], c=df['Purchased'])

# %%
x.describe()
# Out:
#               Age  EstimatedSalary
# count  400.000000       400.000000
# mean    37.655000     69742.500000
# std     10.482877     34096.960282
# min     18.000000     15000.000000
# 25%     29.750000     43000.000000
# 50%     37.000000     70000.000000
# 75%     46.000000     88000.000000
# max     60.000000    150000.000000

# %%
# Import the class
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_scaled=scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
x_scaled=pd.DataFrame(x_scaled, columns=x.columns)

# %%
x_scaled
# Out:
#           Age  EstimatedSalary
# 0    0.023810         0.029630
# 1    0.404762         0.037037
# 2    0.190476         0.207407
# 3    0.214286         0.311111
# 4    0.023810         0.451852
# ..        ...              ...
# 395  0.666667         0.192593
# 396  0.785714         0.059259
# 397  0.761905         0.037037
# 398  0.428571         0.133333
# 399  0.738095         0.155556
#
# [400 rows x 2 columns]

# %%
plt.scatter(x['Age'],x['EstimatedSalary'], c=df['Purchased'])

# %%
# Standardize

# %%
x=np.array([500,800,300,600,900,700,400])

# %%
def standardize(x):
    x_new=(x-x.mean())/x.std()
    return x_new

# %%
x_new=standardize(x)

# %%
x_new
# Out:
# array([-0.5,  1. , -1.5,  0. ,  1.5,  0.5, -1. ])

# %%
x_new.std()
# Out:
# 1.0

# %%
x_new.mean()
# Out:
# 0.0

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_scaled= scaler.fit_transform(x)

# %%
x_scaled=pd.DataFrame(x_scaled, columns=x.columns)
x_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
x_scaled.std()
# Out:
# Age                1.001252
# EstimatedSalary    1.001252
# dtype: float64

# %%
plt.scatter(x['Age'],x['EstimatedSalary'], c=df['Purchased'])
