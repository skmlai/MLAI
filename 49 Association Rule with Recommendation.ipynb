# %%
### create the the Data Set

# %%
dataset = [
    ['Apple','Beer','Rice','Chicken'],
    ['Apple','Beer','Rice'],
    ['Apple','Beer'],
    ['Apple','Pear'],
    ['Milk','Beer','Rice','Chicken'],
    ['Milk','Beer','Rice'],
    ['Milk','Beer'],
    ['Milk','Pear']
]

# %%
dataset
# Out:
# [['Apple', 'Beer', 'Rice', 'Chicken'],
#  ['Apple', 'Beer', 'Rice'],
#  ['Apple', 'Beer'],
#  ['Apple', 'Pear'],
#  ['Milk', 'Beer', 'Rice', 'Chicken'],
#  ['Milk', 'Beer', 'Rice'],
#  ['Milk', 'Beer'],
#  ['Milk', 'Pear']]

# %%
# Convert into Structure formate

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
te=TransactionEncoder()
encoded=te.fit_transform(dataset)

# %%
encoded
# Out:
# array([[ True,  True,  True, False, False,  True],
#        [ True,  True, False, False, False,  True],
#        [ True,  True, False, False, False, False],
#        [ True, False, False, False,  True, False],
#        [False,  True,  True,  True, False,  True],
#        [False,  True, False,  True, False,  True],
#        [False,  True, False,  True, False, False],
#        [False, False, False,  True,  True, False]])

# %%
te.columns_
# Out:
# ['Apple', 'Beer', 'Chicken', 'Milk', 'Pear', 'Rice']

# %%
df=pd.DataFrame(encoded, columns=te.columns_)

# %%
df
# Out:
#    Apple   Beer  Chicken   Milk   Pear   Rice
# 0   True   True     True  False  False   True
# 1   True   True    False  False  False   True
# 2   True   True    False  False  False  False
# 3   True  False    False  False   True  False
# 4  False   True     True   True  False   True
# 5  False   True    False   True  False   True
# 6  False   True    False   True  False  False
# 7  False  False    False   True   True  False

# %%
### apply algorithm

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Find frequent itemset
fre_itemset=apriori(df, min_support=0.25, use_colnames=True)

# %%
fre_itemset
# Out:
#     support               itemsets
# 0     0.500                (Apple)
# 1     0.750                 (Beer)
# 2     0.250              (Chicken)
# 3     0.500                 (Milk)
# 4     0.250                 (Pear)
# 5     0.500                 (Rice)
# 6     0.375          (Apple, Beer)
# 7     0.250          (Apple, Rice)
# 8     0.250        (Chicken, Beer)
# 9     0.375           (Milk, Beer)
# 10    0.500           (Rice, Beer)
# 11    0.250        (Chicken, Rice)
# 12    0.250           (Rice, Milk)
# 13    0.250    (Apple, Rice, Beer)
# 14    0.250  (Chicken, Rice, Beer)
# 15    0.250     (Rice, Milk, Beer)

# %%
# Find frequent itemset
fre_itemset=apriori(df, min_support=0.25, use_colnames=True)

# %%
fre_itemset
# Out:
#     support               itemsets
# 0     0.500                (Apple)
# 1     0.750                 (Beer)
# 2     0.250              (Chicken)
# 3     0.500                 (Milk)
# 4     0.250                 (Pear)
# 5     0.500                 (Rice)
# 6     0.375          (Apple, Beer)
# 7     0.250          (Apple, Rice)
# 8     0.250        (Chicken, Beer)
# 9     0.375           (Milk, Beer)
# 10    0.500           (Rice, Beer)
# 11    0.250        (Chicken, Rice)
# 12    0.250           (Rice, Milk)
# 13    0.250    (Apple, Rice, Beer)
# 14    0.250  (Chicken, Rice, Beer)
# 15    0.250     (Rice, Milk, Beer)

# %%
rules=association_rules(fre_itemset,metric='confidence', min_threshold=0.5)

# %%
rules.shape
# Out:
# (28, 10)

# %%
rules
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 0           (Apple)           (Beer)               0.500               0.750
# 1            (Beer)          (Apple)               0.750               0.500
# 2           (Apple)           (Rice)               0.500               0.500
# 3            (Rice)          (Apple)               0.500               0.500
# 4         (Chicken)           (Beer)               0.250               0.750
# 5            (Milk)           (Beer)               0.500               0.750
# 6            (Beer)           (Milk)               0.750               0.500
# 7            (Rice)           (Beer)               0.500               0.750
# 8            (Beer)           (Rice)               0.750               0.500
# 9         (Chicken)           (Rice)               0.250               0.500
# 10           (Rice)        (Chicken)               0.500               0.250
# 11           (Rice)           (Milk)               0.500               0.500
# 12           (Milk)           (Rice)               0.500               0.500
# 13    (Apple, Rice)           (Beer)               0.250               0.750
# 14    (Apple, Beer)           (Rice)               0.375               0.500
# 15     (Rice, Beer)          (Apple)               0.500               0.500
# 16          (Apple)     (Rice, Beer)               0.500               0.500
# 17           (Rice)    (Apple, Beer)               0.500               0.375
# 18  (Chicken, Rice)           (Beer)               0.250               0.750
# 19  (Chicken, Beer)           (Rice)               0.250               0.500
# 20     (Rice, Beer)        (Chicken)               0.500               0.250
# 21        (Chicken)     (Rice, Beer)               0.250               0.500
# 22           (Rice)  (Chicken, Beer)               0.500               0.250
# 23     (Rice, Milk)           (Beer)               0.250               0.750
# 24     (Rice, Beer)           (Milk)               0.500               0.500
# 25     (Milk, Beer)           (Rice)               0.375               0.500
# 26           (Rice)     (Milk, Beer)               0.500               0.375
# 27           (Milk)     (Rice, Beer)               0.500               0.500
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0     0.375    0.750000  1.000000    0.0000        1.00       0.000000
# 1     0.375    0.500000  1.000000    0.0000        1.00       0.000000
# 2     0.250    0.500000  1.000000    0.0000        1.00       0.000000
# 3     0.250    0.500000  1.000000    0.0000        1.00       0.000000
# 4     0.250    1.000000  1.333333    0.0625         inf       0.333333
# 5     0.375    0.750000  1.000000    0.0000        1.00       0.000000
# 6     0.375    0.500000  1.000000    0.0000        1.00       0.000000
# 7     0.500    1.000000  1.333333    0.1250         inf       0.500000
# 8     0.500    0.666667  1.333333    0.1250        1.50       1.000000
# 9     0.250    1.000000  2.000000    0.1250         inf       0.666667
# 10    0.250    0.500000  2.000000    0.1250        1.50       1.000000
# 11    0.250    0.500000  1.000000    0.0000        1.00       0.000000
# 12    0.250    0.500000  1.000000    0.0000        1.00       0.000000
# 13    0.250    1.000000  1.333333    0.0625         inf       0.333333
# 14    0.250    0.666667  1.333333    0.0625        1.50       0.400000
# 15    0.250    0.500000  1.000000    0.0000        1.00       0.000000
# 16    0.250    0.500000  1.000000    0.0000        1.00       0.000000
# 17    0.250    0.500000  1.333333    0.0625        1.25       0.500000
# 18    0.250    1.000000  1.333333    0.0625         inf       0.333333
# 19    0.250    1.000000  2.000000    0.1250         inf       0.666667
# 20    0.250    0.500000  2.000000    0.1250        1.50       1.000000
# 21    0.250    1.000000  2.000000    0.1250         inf       0.666667
# 22    0.250    0.500000  2.000000    0.1250        1.50       1.000000
# 23    0.250    1.000000  1.333333    0.0625         inf       0.333333
# 24    0.250    0.500000  1.000000    0.0000        1.00       0.000000
# 25    0.250    0.666667  1.333333    0.0625        1.50       0.400000
# 26    0.250    0.500000  1.333333    0.0625        1.25       0.500000
# 27    0.250    0.500000  1.000000    0.0000        1.00       0.000000

# %%
# antecedents means this
# consequents means that

# %%
rules = rules[['antecedents','consequents','support','confidence']]

# %%
rules
# Out:
#         antecedents      consequents  support  confidence
# 0           (Apple)           (Beer)    0.375    0.750000
# 1            (Beer)          (Apple)    0.375    0.500000
# 2           (Apple)           (Rice)    0.250    0.500000
# 3            (Rice)          (Apple)    0.250    0.500000
# 4         (Chicken)           (Beer)    0.250    1.000000
# 5            (Milk)           (Beer)    0.375    0.750000
# 6            (Beer)           (Milk)    0.375    0.500000
# 7            (Rice)           (Beer)    0.500    1.000000
# 8            (Beer)           (Rice)    0.500    0.666667
# 9         (Chicken)           (Rice)    0.250    1.000000
# 10           (Rice)        (Chicken)    0.250    0.500000
# 11           (Rice)           (Milk)    0.250    0.500000
# 12           (Milk)           (Rice)    0.250    0.500000
# 13    (Apple, Rice)           (Beer)    0.250    1.000000
# 14    (Apple, Beer)           (Rice)    0.250    0.666667
# 15     (Rice, Beer)          (Apple)    0.250    0.500000
# 16          (Apple)     (Rice, Beer)    0.250    0.500000
# 17           (Rice)    (Apple, Beer)    0.250    0.500000
# 18  (Chicken, Rice)           (Beer)    0.250    1.000000
# 19  (Chicken, Beer)           (Rice)    0.250    1.000000
# 20     (Rice, Beer)        (Chicken)    0.250    0.500000
# 21        (Chicken)     (Rice, Beer)    0.250    1.000000
# 22           (Rice)  (Chicken, Beer)    0.250    0.500000
# 23     (Rice, Milk)           (Beer)    0.250    1.000000
# 24     (Rice, Beer)           (Milk)    0.250    0.500000
# 25     (Milk, Beer)           (Rice)    0.250    0.666667
# 26           (Rice)     (Milk, Beer)    0.250    0.500000
# 27           (Milk)     (Rice, Beer)    0.250    0.500000

# %%
rules.sort_values(by=['confidence','support'], ascending=False)
# Out:
#         antecedents      consequents  support  confidence
# 7            (Rice)           (Beer)    0.500    1.000000
# 4         (Chicken)           (Beer)    0.250    1.000000
# 9         (Chicken)           (Rice)    0.250    1.000000
# 13    (Apple, Rice)           (Beer)    0.250    1.000000
# 18  (Chicken, Rice)           (Beer)    0.250    1.000000
# 19  (Chicken, Beer)           (Rice)    0.250    1.000000
# 21        (Chicken)     (Rice, Beer)    0.250    1.000000
# 23     (Rice, Milk)           (Beer)    0.250    1.000000
# 0           (Apple)           (Beer)    0.375    0.750000
# 5            (Milk)           (Beer)    0.375    0.750000
# 8            (Beer)           (Rice)    0.500    0.666667
# 14    (Apple, Beer)           (Rice)    0.250    0.666667
# 25     (Milk, Beer)           (Rice)    0.250    0.666667
# 1            (Beer)          (Apple)    0.375    0.500000
# 6            (Beer)           (Milk)    0.375    0.500000
# 2           (Apple)           (Rice)    0.250    0.500000
# 3            (Rice)          (Apple)    0.250    0.500000
# 10           (Rice)        (Chicken)    0.250    0.500000
# 11           (Rice)           (Milk)    0.250    0.500000
# 12           (Milk)           (Rice)    0.250    0.500000
# 15     (Rice, Beer)          (Apple)    0.250    0.500000
# 16          (Apple)     (Rice, Beer)    0.250    0.500000
# 17           (Rice)    (Apple, Beer)    0.250    0.500000
# 20     (Rice, Beer)        (Chicken)    0.250    0.500000
# 22           (Rice)  (Chicken, Beer)    0.250    0.500000
# 24     (Rice, Beer)           (Milk)    0.250    0.500000
# 26           (Rice)     (Milk, Beer)    0.250    0.500000
# 27           (Milk)     (Rice, Beer)    0.250    0.500000

# %%
# above 50% selection  # Filter the rules

# %%
nrules = rules[rules['confidence']>0.5]

# %%
nrules
# Out:
#         antecedents   consequents  support  confidence
# 0           (Apple)        (Beer)    0.375    0.750000
# 4         (Chicken)        (Beer)    0.250    1.000000
# 5            (Milk)        (Beer)    0.375    0.750000
# 7            (Rice)        (Beer)    0.500    1.000000
# 8            (Beer)        (Rice)    0.500    0.666667
# 9         (Chicken)        (Rice)    0.250    1.000000
# 13    (Apple, Rice)        (Beer)    0.250    1.000000
# 14    (Apple, Beer)        (Rice)    0.250    0.666667
# 18  (Chicken, Rice)        (Beer)    0.250    1.000000
# 19  (Chicken, Beer)        (Rice)    0.250    1.000000
# 21        (Chicken)  (Rice, Beer)    0.250    1.000000
# 23     (Rice, Milk)        (Beer)    0.250    1.000000
# 25     (Milk, Beer)        (Rice)    0.250    0.666667

# %%
nrules.shape
# Out:
# (13, 4)

# %%
nrules75 = rules[rules['confidence']>0.85]

# %%
nrules75
# Out:
#         antecedents   consequents  support  confidence
# 4         (Chicken)        (Beer)     0.25         1.0
# 7            (Rice)        (Beer)     0.50         1.0
# 9         (Chicken)        (Rice)     0.25         1.0
# 13    (Apple, Rice)        (Beer)     0.25         1.0
# 18  (Chicken, Rice)        (Beer)     0.25         1.0
# 19  (Chicken, Beer)        (Rice)     0.25         1.0
# 21        (Chicken)  (Rice, Beer)     0.25         1.0
# 23     (Rice, Milk)        (Beer)     0.25         1.0

# %%
nrules[nrules['antecedents']=={'Rice'}]
# Out:
#   antecedents consequents  support  confidence
# 7      (Rice)      (Beer)      0.5         1.0

# %%
nrules[nrules['antecedents']=={'Rice'}]['consequents']
# Out:
# 7    (Beer)
# Name: consequents, dtype: object

# %%
nrules[nrules['antecedents']=={'Apple','Beer'}]['consequents']
# Out:
# 14    (Rice)
# Name: consequents, dtype: object

# %%
nrules.to_csv('rules.csv',index=False)
