# %%
pip install opencv-python pillow scikit-image -U
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import cv2

# %%
# https://mitu.co.in/dataset (Google Drive)
# Download all the file from /images folder and store in your current directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
img1 = cv2.imread('images/she.jpg')

# %%
cv2.imshow('First Image',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# using matplotlip

# %%
import matplotlib.pyplot as plt

# %%
img_plt= plt.imread('images/she.jpg')

# %%
plt.imshow(img_plt)

# %%
from skimage import io

# %%
img=io.imread('images/she.jpg')

# %%
io.imshow(img)

# %%
from PIL import Image

# %%
img_pit= Image.open('images/jungle.jpg')

# %%
img_pit.show()

# %%
img_pit
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x476>

# %%
import tensorflow as tf

# %%
type(img_pit)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
type(img-pit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 type(img-pit)
#
# NameError: name 'pit' is not defined

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img
# Out:
# array([[[73, 74, 76],
#         [74, 75, 77],
#         [75, 76, 78],
#         ...,
#         [44, 55, 57],
#         [43, 54, 56],
#         [41, 52, 54]],
#
#        [[73, 74, 76],
#         [74, 75, 77],
#         [75, 76, 78],
#         ...,
#         [44, 55, 57],
#         [43, 54, 56],
#         [41, 52, 54]],
#
#        [[74, 75, 77],
#         [74, 75, 77],
#         [75, 76, 78],
#         ...,
#         [44, 55, 57],
#         [43, 54, 56],
#         [41, 52, 54]],
#
#        ...,
#
#        [[45, 55, 57],
#         [45, 55, 57],
#         [45, 55, 57],
#         ...,
#         [39, 47, 50],
#         [38, 46, 49],
#         [38, 46, 49]],
#
#        [[43, 53, 55],
#         [43, 53, 55],
#         [44, 54, 56],
#         ...,
#         [38, 46, 49],
#         [38, 46, 49],
#         [37, 45, 48]],
#
#        [[42, 52, 54],
#         [42, 52, 54],
#         [43, 53, 55],
#         ...,
#         [38, 46, 49],
#         [38, 46, 49],
#         [37, 45, 48]]], dtype=uint8)

# %%
from PIL import Image

# %%
img_pil= Image.open('images/jungle.jpg')

# %%
img_pil.show()

# %%
import numpy as np

# %%
img_new= np.zeros([100,100])

# %%
plt.imshow(img_new,cmap='gray')

# %%
img_new[34]=1

# %%
plt.imshow(img_new,cmap='gray')

# %%
img_new[,3]=1
# Out:
#   Cell In[60], line 1
#     img_new[,3]=1
#             ^
# SyntaxError: invalid syntax

# %%
np.random.randint(12,78)
# Out:
# 45

# %%
img_new=np.zeros([100,100], dtype = np.uint8)

# %%
for i in range(100):
    for j in range(100):
        img_new[i,j]= np.random.randint(0,255)

# %%
plt.imshow(img_new, cmap='gray')

# %%
img_gray = cv2.imread('images/jungle.jpg')

# %%
img_gray.shape
# Out:
# (476, 640, 3)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img_plt.shape
# Out:
# (408, 612, 3)

# %%
img1=img_plt[10,10]

# %%
plt.imshow(img1, cmap='gray')

# %%
r=img_plt[:,:,0]
g=img_plt[:,:,1]
b=img_plt[:,:,2]

# %%
r.shape , g.shape, b.shape
# Out:
# ((408, 612), (408, 612), (408, 612))

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap='gray')
plt.subplot(1,3,2)
plt.imshow(g, cmap='gray')
plt.subplot(1,3,3)
plt.imshow(b, cmap='gray')

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap='Reds')
plt.subplot(1,3,2)
plt.imshow(g, cmap='Greens')
plt.subplot(1,3,3)
plt.imshow(b, cmap='Blues')

# %%
new_img=(r+g+b)/3

# %%
plt.imshow(new_img,cmap='gray')

# %%
import cv2
plt.subplot(1,2,1)
# Out:
# <Axes: >

# %%
plt.subplot(1,2,1)
plt.title('Image Read Using CV2')
# Out:
# Text(0.5, 1.0, 'Image Read Using CV2')

# %%
plt.subplot(1,2,1)
plt.title('Image Read Using CV2')
plt.imshow(img1)

# %%
plt.subplot(1,2,2)
plt.title('Image Read using matplotlib')
plt.imshow(img_plt)

# %%
img2=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1,2,1)
plt.title('Image Read Using CV2')
plt.imshow(img2)
plt.subplot(1,2,2)
plt.title('Image Read using matplotlib')
plt.imshow(img_plt)

# %%
import sys

# %%
sys.getsizeof(img2)
# Out:
# 749232

# %%
sys.getsizeof(img_plt)
# Out:
# 144
