# %%
# Name
# Data Set grapes_new.csv
# location: https://mitu.co.in/datasets

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import seaborn as sns

# %% [markdown]
# # 1. Load the dataset

# %%
df=pd.read_csv('grapes_new.csv')

# %%
df.ffill(inplace=True)

# %%
df.bfill(inplace=True)

# %% [markdown]
# # 2.Separate the input and output variables

# %%
x=df.drop('CLASS', axis=1)
y=df['CLASS']

# %%
# 3. Apply the data cleaning (if necessary)

# %% [markdown]
# # 4. Explore the output variable through countplot, pie chart

# %%
plt.figure(figsize=(16, 9))
sns.countplot(x='CLASS', data=df)
plt.title('Countplot of Output Variable')
plt.show()

# %% [markdown]
# # 5. Explore the shape and soil type through countplot, pie chart

# %%
# Countplot for shape
plt.figure(figsize=(16, 9))
plt.subplot(121)
sns.countplot(x='SHAPE', data=df)
plt.title('Countplot of Shape')
#plt.show()

# Pie chart for soil type (assuming the column name is 'soil_type')
plt.subplot(122)
df['SOIL_TYPE'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Soil Type')
plt.ylabel('Soil type')
# Out:
# Text(0, 0.5, 'Soil type')

# %% [markdown]
# # 6. Explore alchohol_per, temperature, avg_humidity, fert_nitro_per, water_phusing kdeplot x

# %%
numeric_vars = ['ALCOHOL_PER', 'TEMPERATURE', 'AVG_HUMIDITY', 'FERT_NITRO_PER', 'WATER_PH']

# %%
plt.figure(figsize=(12, 10))
plt.subplot(1,5,1)
sns.kdeplot(df[var], shade=True)
plt.title(f'KDE Plot of {var}')
plt.tight_layout()
#plt.show()

plt.subplot(1,5,2)
sns.kdeplot(df[var], shade=True)
plt.title(f'KDE Plot of {var}')
plt.tight_layout()
#plt.show()

plt.subplot(1,5,3)
sns.kdeplot(df[var], shade=True)
plt.title(f'KDE Plot of {var}')
plt.tight_layout()
#plt.show()

plt.subplot(1,5,4)
sns.kdeplot(df[var], shade=True)
plt.title(f'KDE Plot of {var}')
plt.tight_layout()
#plt.show()

plt.subplot(1,5,5)
sns.kdeplot(df[var], shade=True)
plt.title(f'KDE Plot of {var}')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rajesh\AppData\Local\Temp\ipykernel_14748\531837963.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[var], shade=True)
# C:\Users\rajesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rajesh\AppData\Local\Temp\ipykernel_14748\531837963.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[var], shade=True)
# ...

# %%
# KDE plots
plt.figure(figsize=(12, 10))
for i, var in enumerate(numeric_vars, 1):
    plt.subplot(3, 2, i)
    sns.kdeplot(df[var], shade=True)
    plt.title(f'KDE Plot of {var}')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rajesh\AppData\Local\Temp\ipykernel_14748\1690144497.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[var], shade=True)
# C:\Users\rajesh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rajesh\AppData\Local\Temp\ipykernel_14748\1690144497.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[var], shade=True)
# ...

# %% [markdown]
# # 7. Apply the data encoding (if necessary)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['SHAPE']=le.fit_transform(df['SHAPE'])#['SOIL_TYPE'],['CLASS']

# %%
df['SOIL_TYPE']=le.fit_transform(df['SOIL_TYPE'])

# %%
df['CLASS']=le.fit_transform(df['CLASS'])

# %%
x=df.drop('CLASS', axis=1)
y=df['CLASS']

# %%
df
# Out:
#      COLOR_INTENSITY  SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER   ASH  \
# 0             120.53      0         16.73        14.23            1.71  2.43
# 1             112.57      0         20.30        13.20            1.78  2.14
# 2             120.78      0         20.81        13.16            2.36  2.67
# 3             134.17      0         19.47        14.37            1.95  2.50
# 4             112.19      1         17.57        13.24            2.59  2.87
# ..               ...    ...           ...          ...             ...   ...
# 189           102.34      0         21.23        12.07            2.16  2.17
# 190           109.80      0         21.67        12.43            1.53  2.29
# 191           103.86      1         22.01        11.79            2.13  2.78
# 192            98.30      0         21.95        12.37            1.63  2.30
# 193           101.33      0         21.60        12.04            4.30  2.38
#
# ...

# %% [markdown]
# # 8. Implement the feature selection method chi2 and find top 5 features.

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
selector = SelectKBest(chi2, k=5)
X_top5 = selector.fit_transform(x, y)

# %%
# Assuming X contains both numeric and categorical variables after encoding
# Select top 5 features based on chi2 test

selected_features = x.columns[selector.get_support(indices=True)]

print("Top 5 Features selected by chi2:")
print(selected_features)
# Out:
# Top 5 Features selected by chi2:
# Index(['COLOR_INTENSITY', 'FLAVANOIDS', 'PROLINE', 'TEMPERATURE',
#        'FER_P2O5_PER'],
#       dtype='object')

# %% [markdown]
# # 9. Apply feature scaling technique and transform

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[ 0.2551645 , -0.75976034, -2.0176571 , ...,  0.05705767,
#          0.94730438,  0.93026051],
#        [-0.30162623, -0.75976034, -0.51029069, ..., -0.04124773,
#          0.5770544 ,  0.93026051],
#        [ 0.27265165, -0.75976034, -0.29495263, ..., -0.04124773,
#         -1.35422351,  0.93026051],
#        ...,
#        [-0.9108784 ,  1.31620453,  0.21172515, ..., -0.21819744,
#          0.51823865,  0.93026051],
#        [-1.29979253, -0.75976034,  0.18639126, ..., -1.04396276,
#          0.35818267, -1.0749677 ],
#        [-1.08784832, -0.75976034,  0.03861024, ..., -1.96803348,
#          0.98587209,  0.93026051]])

# %% [markdown]
# # 10. Perform the cross validation with split ratio 80:20 and stratification

# %%
from sklearn.model_selection import train_test_split

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
x_train, x_test
# Out:
# (     COLOR_INTENSITY  SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER   ASH  \
#  106           152.35      1         23.91        13.45            3.70  2.60
#  183           118.07      0         19.79        14.39            1.87  2.45
#  71            116.49      1         25.01        12.53            5.51  2.64
#  61            125.20      0         20.65        14.22            1.70  2.30
#  97            132.27      0         24.95        12.45            3.03  2.64
#  ..               ...    ...           ...          ...             ...   ...
#  128           102.91      0         21.56        12.21            1.19  1.75
#  160           100.39      0         21.74        12.60            1.34  1.90
#  148            95.90      1         22.69        12.08            1.33  2.30
#  74            113.96      0         25.06        12.93            2.81  2.70
#  118            97.23      1         21.07        12.37            0.94  1.36
#
# ...

# %%
y_train, y_test
# Out:
# (106    1
#  183    2
#  71     1
#  61     0
#  97     1
#        ..
#  128    2
#  160    2
#  148    2
#  74     1
#  118    2
#  Name: CLASS, Length: 155, dtype: int32,
#  179    2
#  105    1
#  18     0
#  67     1
#  129    2
#  111    1
#  63     0
#  190    2
#  154    2
#  157    2
#  80     1
#  22     0
#  124    2
#  99     1
#  103    1
#  51     0
#  38     0
#  145    2
#  140    2
#  20     0
#  69     1
#  189    2
#  28     0
#  42     0
#  23     0
#  7      0
#  65     1
#  161    2
#  151    2
#  14     0
#  152    2
#  158    2
#  53     0
#  98     1
#  77     1
#  150    2
#  110    1
#  10     0
#  165    2
#  Name: CLASS, dtype: int32)

# %% [markdown]
# # 11. Implement all classification algorithm to check the accuracy on the data.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
clf_log=LogisticRegression()
clf_dt=DecisionTreeClassifier(random_state=0)
clf_rf=RandomForestClassifier(random_state=0,n_estimators=10)
clf_knn=SVC(random_state=0, kernel='poly')
clf_nb=GaussianNB()

# %%
clf_log.fit(x_train,y_train)
# Out:
# C:\Users\rajesh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
clf_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
clf_knn.fit(x_train,y_train)
# Out:
# SVC(kernel='poly', random_state=0)

# %%
clf_nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_log=clf_log.predict(x_test)
y_pred_dt=clf_dt.predict(x_test)
y_pred_rf=clf_rf.predict(x_test)
y_pred_knn=clf_knn.predict(x_test)
#y_pred_svm=clf_svm.predict(x_text)
y_pred_nb=clf_nb.predict(x_test)

# %%
print('Log:', accuracy_score(y_test,y_pred_log))
print('DT:',accuracy_score(y_test,y_pred_dt))
print('RF:',accuracy_score(y_test,y_pred_rf))
print('KNN:',accuracy_score(y_test,y_pred_knn))
#print('SVM:',accuracy_score(y_test,y_pred_svm))
print('NB:',accuracy_score(y_test,y_pred_nb))
# Out:
# Log: 0.9230769230769231
# DT: 0.9487179487179487
# RF: 1.0
# KNN: 0.5897435897435898
# NB: 0.9487179487179487

# %% [markdown]
# # 12. Create the dataframe which shows the comparison of accuracy and speed of different classification algorithm implemented on this dataset.

# %%
from sklearn.ensemble import VotingClassifier

# %%
vt=VotingClassifier(estimators=[('log',clf_log),
                               ('ct',clf_dt),
                               ('rf',clf_rf),
                               ('knn',clf_knn),
                              # ('svm',clf_svm),
                               ('nb',clf_nb)])

# %%
vt.fit(x_train,y_train)
# Out:
# C:\Users\rajesh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# VotingClassifier(estimators=[('log', LogisticRegression()),
#                              ('ct', DecisionTreeClassifier(random_state=0)),
#                              ('rf',
#                               RandomForestClassifier(n_estimators=10,
#                                                      random_state=0)),
#                              ('knn', SVC(kernel='poly', random_state=0)),
#                              ('nb', GaussianNB())])

# %%
y_pred=vt.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9743589743589743

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        13
#            1       1.00      1.00      1.00        11
#            2       0.94      1.00      0.97        15
#
#     accuracy                           0.97        39
#    macro avg       0.98      0.97      0.98        39
# weighted avg       0.98      0.97      0.97        39

# %%
#Create the dataframe which shows the comparison of accuracy and speed of different classification algorithm implemented on this dataset.

# %%
df = {  
    'Logistic Regression': 0.5,  # 
    'Decision Tree': 2.3,
    'Random Forest': 4.7
}

results_df['Speed (seconds)'] = results_df['Classifier'].map(speed_metrics)

print(results_df)
# Out:
#             Classifier  Accuracy  Speed (seconds)
# 0  Logistic Regression  0.923077              0.5
# 1        Decision Tree  1.000000              2.3
# 2        Random Forest  1.000000              4.7

# %%
import time

# %%
clf_log.fit(x_train,y_train)
clf_log.fit(x_train,y_train)
clf_dt.fit(x_train,y_train)
clf_rf.fit(x_train,y_train)
clf_knn.fit(x_train,y_train)
clf_nb.fit(x_train,y_train)
