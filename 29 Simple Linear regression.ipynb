# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Height in cm
x= np.array([[151],[174],[138],[186],[128],[136],[179],[163],[152],[131]])
y=np.array([63,81,56,91,47,57,76,72,62,48])

# %%
x,y
# Out:
# (array([[151],
#         [174],
#         [138],
#         [186],
#         [128],
#         [136],
#         [179],
#         [163],
#         [152],
#         [131]]),
#  array([63, 81, 56, 91, 47, 57, 76, 72, 62, 48]))

# %%
plt.title('Height Vs Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.grid()
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
# import the class

# %%
from sklearn.linear_model import LinearRegression

# %%
# create the object
regressor=LinearRegression()

# %%
# train the algorithm
regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
# Value of m
regressor.coef_
# Out:
# array([0.67461045])

# %%
#value of c
regressor.intercept_
# Out:
# -38.45508707607698

# %%
167 * 0.67461045 - 38.45508707607698
# Out:
# 74.20485807392302

# %%
200 * 0.67461045 - 38.45508707607698
# Out:
# 96.46700292392302

# %%
y_new=x * 0.67461045 - 38.45508707607698

# %%
plt.title('Height Vs Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.grid()
plt.scatter(x,y, color='red')
plt.plot(x,y_new, color='green')

# %%
#####

# %%
import pandas as pd

# %%
result =pd.DataFrame({
    'actual':y,
    'predicted':y_new.flatten()
})
result
# Out:
#    actual  predicted
# 0      63  63.411091
# 1      81  78.927131
# 2      56  54.641155
# 3      91  87.022457
# 4      47  47.895051
# 5      57  53.291934
# 6      76  82.300183
# 7      72  71.506416
# 8      62  64.085701
# 9      48  49.918882
